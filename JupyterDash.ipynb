# %%
#Important components in Dash 
#1. Dash components which include sliders, checkbox, date picker , the drop down( help improve the interactive capabilities)
#2. Plotly Graphs  which include mapbox, scatter box, the line chart, the bar-chart
#3. The callback - Connects the Dash components and plotly components.


#Both the Dash components and the Plotly graphs go inside the Layout components. 
#The callback is outside the app layout.

# %%
#Installing the Jupyter dash notebook 
# !pip install jupyter_dash
# Out:
# Requirement already satisfied: jupyter_dash in c:\users\derrick.muiru\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: dash in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (1.21.0)
# Requirement already satisfied: requests in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: ansi2html in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: ipython in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: retrying in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: flask in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ipykernel in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: dash-html-components==1.1.4 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.4)
# Requirement already satisfied: dash-table==4.12.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.12.0)
# Requirement already satisfied: flask-compress in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-core-components==1.17.1 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.17.1)
# Requirement already satisfied: future in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\derrick.muiru\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.2.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\derrick.muiru\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: jupyter-client in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: pygments in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: colorama in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: decorator in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: backcall in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\derrick.muiru\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\derrick.muiru\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\derrick.muiru\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)

# %%
from jupyter_dash import JupyterDash

# %%
#Dash is Plotly’s open source Python (and R and Julia!)
#framework for building full stack analytic web applications# using pure Python (no JavaScript required).
import dash
print("dash: ",dash.__version__)

#The Dash Core Component library contains a set of higher-level components like sliders, graphs, dropdowns, tables, and more.
import dash_core_components as dcc
print("dash_core_components: ",dcc.__version__)

#Dash provides all of the available HTML tags as user-friendly Python classes. This chapter explains how this works 
#and the few important key differences between Dash HTML components and standard html.
import dash_html_components as html
print("dash_html_components: ",html.__version__)

#pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
#built on top of the Python programming language. Install ...
import pandas as pd
print("pandas: ",pd.__version__)

#Plotly Express is a terse, consistent, high-level API for creating figures.
import plotly.express as px

from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output
 #Used in these callback definitions
# Out:
# dash:  1.21.0
# dash_core_components:  1.17.1
# dash_html_components:  1.1.4
# pandas:  1.2.4

# %%
#Lets try something from the Dash Documentation page.

# %%
# Load Data
df = px.data.tips()
# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")]
)
def update_figure(colorscale):
    return px.scatter(
        df, x="total_bill", y="tip", color="size",
        color_continuous_scale=colorscale,
        render_mode="webgl", title="Tips"
    )
# Run app and display result inline in the notebook
app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#Okay we have seen how these Code Examples are written. Now lets start.

# %%
#Start the app.
app = dash.Dash(__name__)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Derrick.Muiru'

# %%
df= pd.read_csv("intro_bees.csv")

# %%
df
# Out:
#      Program  Year        Period    State  ANSI        Affected by  \
# 0     SURVEY  2019  JAN THRU MAR  Alabama     1            Disease
# 1     SURVEY  2019  JAN THRU MAR  Alabama     1              Other
# 2     SURVEY  2019  JAN THRU MAR  Alabama     1         Pesticides
# 3     SURVEY  2019  JAN THRU MAR  Alabama     1  Pests_excl_Varroa
# 4     SURVEY  2019  JAN THRU MAR  Alabama     1            Unknown
# ...      ...   ...           ...      ...   ...                ...
# 4585  SURVEY  2015  OCT THRU DEC  Wyoming    56              Other
# 4586  SURVEY  2015  OCT THRU DEC  Wyoming    56         Pesticides
# 4587  SURVEY  2015  OCT THRU DEC  Wyoming    56  Pests_excl_Varroa
# 4588  SURVEY  2015  OCT THRU DEC  Wyoming    56            Unknown
# 4589  SURVEY  2015  OCT THRU DEC  Wyoming    56       Varroa_mites
#
#       Pct of Colonies Impacted state_code
# 0                          1.8         AL
# 1                          3.1         AL
# 2                          0.3         AL
# 3                         22.7         AL
# 4                          9.0         AL
# ...                        ...        ...
# 4585                      11.3         WY
# 4586                      10.5         WY
# 4587                       3.3         WY
# 4588                       3.9         WY
# 4589                      45.0         WY
#
# [4590 rows x 8 columns]

# %%
df = df.groupby(['State','ANSI','Affected by','Year','state_code'])[['Pct of Colonies Impacted']].mean()
df.reset_index(inplace = True)

# %%
df
# Out:
#         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns]

# %%
#App layouts - What goes in here are the components(graph, dropdowns, slides) and any HTML code needed.
app.layout = html.Div([
    html.H1("Bees affected by different Diseases", style ={'text-align':'center'}),
    dcc.Dropdown(id = "slct_year",
                options = [
                    {"label":"2015","value":2015},
                    {"label":"2016","value":2016},
                    {"label":"2017","value":2017},
                    {"label":"2018","value":2018}],
                multi = False,
                value = 2015,
                style = {'width':"40%"}),
    html.Div(id = 'output_container', children =[]),
    html.Br(),
    
    dcc.Graph(id = 'my_bee_map',figure= {})
])

# %%
# Connect the Plotly graphs with Dash Components
@app.callback(
    [Output(component_id='output_container', component_property='children'),
     Output(component_id='my_bee_map', component_property='figure')],
    [Input(component_id='slct_year', component_property='value')]
)
def update_graph(option_slctd):
    print(option_slctd)
    print(type(option_slctd))

    container = "The year chosen by user was: {}".format(option_slctd)

    dff = df.copy()
    dff = dff[dff["Year"] == option_slctd]
    dff = dff[dff["Affected by"] == "Varroa_mites"]

    # Plotly Express
    fig = px.choropleth(
        data_frame=dff,
        locationmode='USA-states',
        locations='state_code',
        scope="usa",
        color='Pct of Colonies Impacted',
        hover_data=['State', 'Pct of Colonies Impacted'],
        color_continuous_scale=px.colors.sequential.YlOrRd,
        labels={'Pct of Colonies Impacted': '% of Bee Colonies'},
        template='plotly_dark'
    )

#     #Plotly Graph Objects (GO)
#     fig = go.Figure(
#          data=[go.Choropleth(
#             locationmode='USA-states',
#              locations=dff['state_code'],
#              z=dff["Pct of Colonies Impacted"].astype(float),
#              colorscale='Reds',
#          )]
#      )
#     fig.update_layout(
#          title_text="Bees Affected by Mites in the USA",
#          title_xanchor="center",
#          title_font=dict(size=24),
#          title_x=0.5,
#          geo=dict(scope='usa'),
#      )

    return container


# ------------------------------------------------------------------------------
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0b2793525afa> in update_figure(colorscale='plasma')
#      22 )
#      23 def update_figure(colorscale):
# ---> 24     return px.scatter(
#         global px.scatter = <function scatter at 0x0000019B62F11670>
#         global df =         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns]
#         global x = undefined
#         global y = undefined
#         global color = undefined
#         global color_continuous_scale = undefined
#         colorscale = 'plasma'
#         global render_mode = undefined
#         global title = undefined
#      25         df, x="total_bill", y="tip", color="size",
#      26         color_continuous_scale=colorscale,
#
# ~\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter(
#     data_frame=        State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns],
#     x='total_bill',
#     y='tip',
#     color='size',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale='plasma',
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='webgl',
#     title='Tips',
#     template=None,
#     width=None,
#     height=None
# )
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         global make_figure = <function make_figure at 0x0000019B62E44700>
#         global args = undefined
#         global locals = undefined
#         global constructor = undefined
#         global go.Scatter = <class 'plotly.graph_objs._scatter.Scatter'>
#      67
#      68
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'plasma', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    1931     apply_default_cascade(args)
#    1932
# -> 1933     args = build_dataframe(args, constructor)
#         args = {'data_frame':         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns], 'x': 'total_bill', 'y': 'tip', 'color': 'size', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': 'plasma', 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'webgl', 'title': 'Tips', 'template': None, 'width': None, 'height': None}
#         global build_dataframe = <function build_dataframe at 0x0000019B62E443A0>
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    1934     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1935         args = process_dataframe_hierarchy(args)
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'plasma', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1403     # now that things have been prepped, we do the systematic rewriting of `args`
#    1404
# -> 1405     df_output, wide_id_vars = process_args_into_dataframe(
#         df_output = undefined
#         global wide_id_vars = undefined
#         global process_args_into_dataframe = <function process_args_into_dataframe at 0x0000019B62E44310>
#         args = {'data_frame':         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns], 'x': 'total_bill', 'y': 'tip', 'color': 'size', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': 'plasma', 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'webgl', 'title': 'Tips', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1406         args, wide_mode, var_name, value_name
#    1407     )
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'plasma', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1205                         if argument == "index":
#    1206                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207                         raise ValueError(err_msg)
#         global ValueError = undefined
#         err_msg = "Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['State', 'ANSI', 'Affected by', 'Year', 'state_code', 'Pct of Colonies Impacted'] but received: total_bill"
#    1208                 elif length and len(df_input[argument]) != length:
#    1209                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['State', 'ANSI', 'Affected by', 'Year', 'state_code', 'Pct of Colonies Impacted'] but received: total_bill
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0b2793525afa> in update_figure(colorscale='oranges')
#      22 )
#      23 def update_figure(colorscale):
# ---> 24     return px.scatter(
#         global px.scatter = <function scatter at 0x0000019B62F11670>
#         global df =         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns]
#         global x = undefined
#         global y = undefined
#         global color = undefined
#         global color_continuous_scale = undefined
#         colorscale = 'oranges'
#         global render_mode = undefined
#         global title = undefined
#      25         df, x="total_bill", y="tip", color="size",
#      26         color_continuous_scale=colorscale,
#
# ~\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter(
#     data_frame=        State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns],
#     x='total_bill',
#     y='tip',
#     color='size',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale='oranges',
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='webgl',
#     title='Tips',
#     template=None,
#     width=None,
#     height=None
# )
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         global make_figure = <function make_figure at 0x0000019B62E44700>
#         global args = undefined
#         global locals = undefined
#         global constructor = undefined
#         global go.Scatter = <class 'plotly.graph_objs._scatter.Scatter'>
#      67
#      68
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'oranges', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    1931     apply_default_cascade(args)
#    1932
# -> 1933     args = build_dataframe(args, constructor)
#         args = {'data_frame':         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns], 'x': 'total_bill', 'y': 'tip', 'color': 'size', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': 'oranges', 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'webgl', 'title': 'Tips', 'template': None, 'width': None, 'height': None}
#         global build_dataframe = <function build_dataframe at 0x0000019B62E443A0>
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    1934     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1935         args = process_dataframe_hierarchy(args)
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'oranges', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1403     # now that things have been prepped, we do the systematic rewriting of `args`
#    1404
# -> 1405     df_output, wide_id_vars = process_args_into_dataframe(
#         df_output = undefined
#         global wide_id_vars = undefined
#         global process_args_into_dataframe = <function process_args_into_dataframe at 0x0000019B62E44310>
#         args = {'data_frame':         State  ANSI   Affected by  Year state_code  Pct of Colonies Impacted
# 0     Alabama     1       Disease  2015         AL                     0.050
# 1     Alabama     1       Disease  2016         AL                     1.200
# 2     Alabama     1       Disease  2017         AL                     2.250
# 3     Alabama     1       Disease  2018         AL                     1.300
# 4     Alabama     1       Disease  2019         AL                     1.800
# ...       ...   ...           ...   ...        ...                       ...
# 1345  Wyoming    56  Varroa_mites  2015         WY                    23.375
# 1346  Wyoming    56  Varroa_mites  2016         WY                    19.475
# 1347  Wyoming    56  Varroa_mites  2017         WY                    23.525
# 1348  Wyoming    56  Varroa_mites  2018         WY                    22.425
# 1349  Wyoming    56  Varroa_mites  2019         WY                     0.700
#
# [1350 rows x 6 columns], 'x': 'total_bill', 'y': 'tip', 'color': 'size', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': 'oranges', 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'webgl', 'title': 'Tips', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1406         args, wide_mode, var_name, value_name
#    1407     )
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'size', 'color_continuous_midpoint': None, 'color_continuous_scale': 'oranges', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':         State  ANSI   Affected by  Year state_co...                   0.700
#
# [1350 rows x 6 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1205                         if argument == "index":
#    1206                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207                         raise ValueError(err_msg)
#         global ValueError = undefined
#         err_msg = "Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['State', 'ANSI', 'Affected by', 'Year', 'state_code', 'Pct of Colonies Impacted'] but received: total_bill"
#    1208                 elif length and len(df_input[argument]) != length:
#    1209                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['State', 'ANSI', 'Affected by', 'Year', 'state_code', 'Pct of Colonies Impacted'] but received: total_bill
